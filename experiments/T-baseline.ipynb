# %% [markdown]
# # Token Model — Baseline

# %%
# %tb
import os, json, math, random, glob
from pathlib import Path
from dataclasses import dataclass
from typing import List, Tuple, Optional, Dict
from collections import defaultdict

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm import tqdm
from torch.optim import AdamW


from modules.plotting import MetricLog, plot_metrics
from modules.hand_testing import hand_test_repl
from modules.best_model_saver import BestModelSaver
from modules.datasets.loading import load_files
from modules.datasets.token_dataset import *
from modules.models.T_baseline_model import *
from modules.tokenizers.base_tokenizer import *

import warnings
warnings.filterwarnings("ignore")

WORKDIR = r'C:\Users\Roman\Documents\Projects\code_autocomplete'
# WORKDIR = r'C:\Programing\code_autocomplete'
print(f"WORKDIR: {WORKDIR}")
TOKEN_MODEL_NAME = 'token_model_baseline'


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[Device] {device}")
print(f"PyTorch версия: {torch.__version__}")
print(f"CUDA доступна: {torch.cuda.is_available()}")
print(f"Версия CUDA, под которую собран PyTorch: {torch.version.cuda}")
print(f"Количество GPU: {torch.cuda.device_count()}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 128
#     124     if args.no_test: return
#     125     hand_test_repl(tok_model, None, tokenizer, None, device)
#     126
#     127
# --> 128 main()
#
# Cell In[3], line 103, in main()
#      99         print("  Prepairing TOKEN model")
#     100
#     101         all_ids_tr = []
#     102         for t in tr_txt:
# --> 103             all_ids_tr.extend(tokenizer.encode(t))
#     104         all_ids_va = []
#     105         for t in va_txt:
#     106             all_ids_va.extend(tokenizer.encode(t))
#
# File c:\Users\Roman\Documents\Projects\code_autocomplete\experiments\modules\tokenizers\base_tokenizer.py:123, in CodeTokenizer.encode(self, text)
#     120     else:
#     121         # char fallback — should rarely hit <UNK> after the build fix
#     122         for ch in tok:
# --> 123             ids.append(self.token2id.get(ch, SPECIAL["<UNK>"]))
#     124 ids.append(SPECIAL["<EOS>"])
#     125 return ids
#
# KeyboardInterrupt:
# WORKDIR: C:\Users\Roman\Documents\Projects\code_autocomplete
# [Device] cuda
# PyTorch версия: 2.6.0+cu124
# CUDA доступна: True
# Версия CUDA, под которую собран PyTorch: 12.4
# Количество GPU: 1

# %% [markdown]
# ## Training loop

# %%
def _clip_norm(model: nn.Module, max_norm: float = 1.0) -> float:
    return nn.utils.clip_grad_norm_(model.parameters(), max_norm).item()


def train_token_model(
    model:      TokenModel,
    train_dl:   DataLoader,
    val_dl:     DataLoader,
    epochs:     int,
    lr:         float,
    device:     torch.device,
    saver:      BestModelSaver,
    log:        MetricLog,
    plot_dir:   str,
):
    tqdm.write(f"[Line] DataLoader — {len(train_dl)} train batches, "
               f"{len(val_dl)} val batches")

    opt = AdamW(model.parameters(), lr=lr, weight_decay=1e-2)
    sched = CosineAnnealingLR(opt, T_max=epochs, eta_min=lr / 20)
    crit = nn.CrossEntropyLoss(ignore_index=SPECIAL["<PAD>"])

    for ep in range(1, epochs + 1):
        # train
        print(f"Epoch {ep}")
        model.train()
        t_loss = t_steps = 0
        for x, y in tqdm(train_dl, desc=f"[Token] Epoch {ep}/{epochs} train",
                 leave=False, unit="batch"):
            x, y = x.to(device), y.to(device)
            logits = model(x)
            loss = crit(logits.view(-1, logits.size(-1)), y.view(-1))
            opt.zero_grad()
            loss.backward()
            gn = _clip_norm(model)
            opt.step()
            t_loss += loss.item()
            t_steps += 1

        tl = t_loss / t_steps

        # val
        model.eval()
        v_loss = v_acc = v_steps = 0
        with torch.no_grad():
            for x, y in tqdm(val_dl, desc=f"[Token] Epoch {ep}/{epochs} val  ",
                 leave=False, unit="batch"):
                x, y = x.to(device), y.to(device)
                logits = model(x)
                loss = crit(logits.view(-1, logits.size(-1)), y.view(-1))
                v_loss += loss.item()
                preds = logits.argmax(-1)
                mask = (y != SPECIAL["<PAD>"])
                v_acc += (preds[mask] == y[mask]).float().mean().item()
                v_steps += 1
        vl = v_loss / v_steps if v_steps else tl
        va = v_acc / v_steps if v_steps else 0.0
        sched.step()

        log.append(train_loss=tl, val_loss=vl,
                   train_ppl=math.exp(min(tl, 20)), val_ppl=math.exp(min(vl, 20)),
                   lr=opt.param_groups[0]["lr"], token_acc=va, grad_norm=gn)
        tqdm.write(
            f"[Token  ep {ep:3d}] train_loss={tl:.4f}  val_loss={vl:.4f}"
            f"  ppl={math.exp(min(vl,20)):.1f}  val_acc={va:.3f}"
            f"  lr={opt.param_groups[0]['lr']:.2e}"
        )

        saver.save(model, vl, ep)
        if ep % max(1, epochs // 5) == 0 or ep == epochs:
            plot_metrics(log, f"{TOKEN_MODEL_NAME.replace('_', ' ')} — Epoch {ep}",
                         f"{plot_dir}/{TOKEN_MODEL_NAME}_ep{ep:02d}.png")

    plot_metrics(log, f"{TOKEN_MODEL_NAME.replace('_', ' ')} — Final", f"{plot_dir}/{TOKEN_MODEL_NAME}_final.png")

# %% [markdown]
# ## Main

# %%
class Arguments():
    def __init__(self, data_dir: str = f"{WORKDIR}/Clean_Dataset", ckpt_dir: str = f"{WORKDIR}/checkpoints/{TOKEN_MODEL_NAME}",
                    plot_dir: str = F"{WORKDIR}/plots/{TOKEN_MODEL_NAME}", tokenizer: str = "tokenizer.json", 
                    epochs: int = 5, batch: int = 32, lr: float = 5e-4,
                    ctx: int = 128, d_model: int = 256, n_layers: int = 4,
                    n_heads: int = 8, vocab_size: int = 16000, max_files: int = 0,
                    val_split: float = 0.1, seed: int = 42, for_usage: bool = False,
                    skip_token: bool = False, skip_line: bool = False, test: bool = False,
                    no_test: bool = False):
        self.data_dir = data_dir
        self.ckpt_dir = ckpt_dir
        self.plot_dir = plot_dir
        self.tokenizer = tokenizer
        self.epochs = epochs
        self.batch = batch
        self.lr = lr
        self.ctx = ctx
        self.d_model = d_model
        self.n_layers = n_layers
        self.n_heads = n_heads
        self.vocab_size = vocab_size
        self.max_files = max_files
        self.val_split = val_split
        self.seed = seed
        self.skip_token = skip_token
        self.skip_line = skip_line
        self.test = test
        self.for_usage = for_usage
        self.no_test = no_test


def main():
    # args = Arguments(max_files=1211)
    args = Arguments(test=True)
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)

    os.makedirs(args.ckpt_dir, exist_ok=True)
    os.makedirs(args.plot_dir,  exist_ok=True)

    # tokenizer
    if os.path.exists(args.tokenizer):
        print(f"[Tokenizer] loading {args.tokenizer}")
        tokenizer = CodeTokenizer.load(args.tokenizer)
    else:
        print("[Tokenizer] building from data …")
        texts = load_files(args.data_dir, args.max_files)
        print(f"DEBUG args.vocab_size = {args.vocab_size!r} (type: {type(args.vocab_size)})")
        tokenizer = CodeTokenizer(vocab_size=args.vocab_size)
        tokenizer.build(texts)
        tokenizer.save(args.tokenizer)
        test = "x = foo(1, 2)"
        ids = tokenizer.encode(test)
        print("tokens:", [tokenizer.id2token[i] for i in ids])
        print("UNK count:", sum(1 for i in ids if i == SPECIAL["<UNK>"]))

    cfg = ModelCfg(
        vocab=tokenizer.vocab, d_model=args.d_model,
        n_heads=args.n_heads,  n_layers=args.n_layers,
        d_ff=args.d_model * 4, max_len=args.ctx + 32,
    )

    torch.serialization.add_safe_globals([ModelCfg])

    # test-only mode
    if args.test and not args.no_test:
        tm = TokenModel(cfg).to(device)
        tok_paths = sorted(glob.glob(str(Path(args.ckpt_dir + TOKEN_MODEL_NAME + "_*.pt"))))
        if tok_paths:
            ck = torch.load(tok_paths[0], map_location=device, weights_only=False)
            tm.load_state_dict(ck["model_state"])
            print(f"[Loaded] token model from {tok_paths[0]}")
    
        hand_test_repl(tm, None, tokenizer, None, device)
        return
    

    # load data
    print("[Loading] Started loading")
    texts = load_files(args.data_dir, args.max_files)
    if not texts:
        print("[ERROR] no data files found. Please put .py files in --data_dir")
        return
    print("[Loading] Ended loading")

    random.shuffle(texts)
    split = max(1, int(len(texts) * (1 - args.val_split)))
    tr_txt = texts[:split]
    va_txt = texts[split:]
    
    # TOKEN MODEL
    if not args.skip_token:
        print("  Prepairing TOKEN model")

        all_ids_tr = []
        for t in tr_txt:
            all_ids_tr.extend(tokenizer.encode(t))
        all_ids_va = []
        for t in va_txt:
            all_ids_va.extend(tokenizer.encode(t))

        tr_ds = TokenDataset(all_ids_tr, args.ctx)
        va_ds = TokenDataset(all_ids_va, args.ctx)
        tr_dl = DataLoader(tr_ds, args.batch, shuffle=True,  num_workers=0, pin_memory=True)
        va_dl = DataLoader(va_ds, args.batch, shuffle=False, num_workers=0, pin_memory=True)

        tok_model = TokenModel(cfg).to(device)
        n_params = sum(p.numel() for p in tok_model.parameters() if p.requires_grad)
        print(f"[Token Model] {n_params/1e6:.2f}M parameters")

        tok_saver = BestModelSaver(args.ckpt_dir, TOKEN_MODEL_NAME)
        tok_log = MetricLog()
        print("  Training TOKEN model")
        train_token_model(tok_model, tr_dl, va_dl, args.epochs, args.lr,
                          device, tok_saver, tok_log, args.plot_dir)

    # interactive test
    if args.no_test: return
    hand_test_repl(tok_model, None, tokenizer, None, device)


main()
# Out:
# [Tokenizer] loading tokenizer.json
#   Python Autocomplete — Interactive Test
#   Commands: :token <prefix> | :temp <float> | :k <int> | :quit
#
#   ← token completion: def fibonac_maxsize_save10px10px10px10px10px10pxdefault_optionsPredictionMode_maxsize_maxsize_maxsize_maxsize_maxsize_maxsizezzzzoomed_display
#
#   ← token completion: def fibonacci(zoomed_displayhash_name10pxy0_maxsize_maxsize_maxsizecollaterlanguage_modelslanguage_models_maxsize_maxsizezoomed_displayzzzzoomed_displayzoomed_displayzimplements
#
#   ← token completion: for i in ra10px10px10pximplementsassert_allclosefeaturesy0_maxsizezzapproximateadd_gesturelanguage_models_maxsize_maxsize_maxsize_maxsizezoomed_displayzoomed_displayzoomed_display
#
#   ← token completion: if x == Nocurrentlycurrently_maxsizefeaturesy0_maxsizefeaturesy0y0_maxsizelanguage_modelslanguage_modelsPredictionModecurrentlycurrently_maxsizefeatureslanguage_models10px_maxsize
#
#   ← token completion: self.value = compadd_gestureadd_gesturetrsm10px10pxz_maxsizey0_maxsize_maxsizez_maxsize_maxsize_maxsize_maxsize_maxsizefeatureszzz
#
#   ← token completion: return self.add_gestureadd_gestureadd_gestureadd_gestureout_filters_maxsize_maxsize_maxsizey0featuresy0input_file_maxsizedefault_optionsPredictionModelanguage_modelsimplements_maxsize_maxsize_maxsize
#
#   ← token completion: while Tradd_gestureadd_gesture_maxsize_maxsizetrsm_maxsizefeatures_maxsizeimplements_maxsize_maxsizeinput_fileinput_filelanguage_modelsPredictionModeadd_gesturelinesimplements_maxsize_maxsize
#
#   ← token completion: class MyModel(nn.out_filtersadd_gestureadd_gestureadd_gesturefeaturesz_maxsize_maxsize_maxsize_maxsize_maxsize_maxsizezimplements_maxsize_maxsize_maxsize_maxsize_maxsizez
#
#   ← token completion: result = [x for x in10px10px_maxsize_maxsizeinput_fileinput_filelanguage_modelslanguage_modelslanguage_modelsapproximate_maxsize_maxsize_maxsizezlanguage_modelsimplements10px10pxTests10px
#
#   ← token completion: with open(filena10px10pxy0hash_namehash_namey0approximatehash_nameimplementsPredictionModescatterpolargl_maxsize_maxsizefeaturesimplements10pxlanguage_modelszzz
